# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
from numpy.random import randn

# %%
arr = np.array([[1,2,np.nan],[np.nan,3,4]])

# %% [raw]
# arr

# %%
arr
# Out:
# array([[  1.,   2.,  nan],
#        [ nan,   3.,   4.]])

# %%
dframe1 = DataFrame(arr, index=['a','b'],columns
                    = ['one','two','three'])

# %%
dframe1
# Out:
#    one  two  three
# a  1.0  2.0    NaN
# b  NaN  3.0    4.0

# %%
dframe1.sum()
# Out:
# one      1.0
# two      5.0
# three    4.0
# dtype: float64

# %%
dframe1.sum(axis=1)
# Out:
# a    3.0
# b    7.0
# dtype: float64

# %%
dframe1.min()
# Out:
# one      1.0
# two      2.0
# three    4.0
# dtype: float64

# %%
dframe1.idxmin()
# Out:
# one      a
# two      a
# three    b
# dtype: object

# %%
dframe1.idxmax()
# Out:
# one      a
# two      b
# three    b
# dtype: object

# %% [raw]
#     dfram1.cumsum()

# %%
dframe1.cumsum()
# Out:
#    one  two  three
# a  1.0  2.0    NaN
# b  NaN  5.0    4.0

# %%
dframe1.describe()
# Out:
#        one       two  three
# count  1.0  2.000000    1.0
# mean   1.0  2.500000    4.0
# std    NaN  0.707107    NaN
# min    1.0  2.000000    4.0
# 25%    1.0  2.250000    4.0
# 50%    1.0  2.500000    4.0
# 75%    1.0  2.750000    4.0
# max    1.0  3.000000    4.0

# %%
from pandas_datareader import data as web

# %%
import datetime as dt

# %%
start = dt.datetime(2013,1,1)
end = dt.datetime(2014,1,1)

# %%
f = web.DataReader("F",'yahoo',start, end)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /Users/shotashimizu/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/urllib3/connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# /Users/shotashimizu/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      59
# ---> 60     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61         af, socktype, proto, canonname, sa = res
#
# /Users/shotashimizu/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     731     addrlist = []
# ...

# %%
3-3
# Out:
# 0

# %%
import pandas_datareader.data as pdweb
from pandas_datareader import data as pdr
import fix_yahoo_finance as yf # must pip install first 
yf.pdr_override()
# Out:
# /Users/shotashimizu/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/fix_yahoo_finance/__init__.py:43: DeprecationWarning:
#     Auto-overriding of pandas_datareader's get_data_yahoo() is deprecated and will be removed in future versions.
#     Use pdr_override() to explicitly override it.
#   DeprecationWarning)

# %%
data = pdr.get_data_yahoo('APPL','2017-05-20','2017-05-23')
# Out:
# [*********************100%***********************]  1 of 1 downloaded

# %%
    symbols=['FRED/GDP']
    import quandl as qdl
    start_date = '2016-01-01'
    end_date = '2017-05-22'
    for symbol in symbols:

        quandldata = qdl.get_table("WIKI/PRICES",qopts={"columns":["date", "adj_close"]},
        ticker=symbol, date = {'gte': start_date,'lte' : end_date})
        # specify that the quandldata df has index col = 'date'
        quandldata = quandldata.set_index(["date"], drop=True)
        # rename col adj close to the respective symbol to prevent clash w/ same name for all cols
        quandldata = quandldata.rename(columns={'adj_close': symbol})
        df = df.join(quandldata)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-56-62138f2d67f9> in <module>()
#       6
#       7     quandldata = qdl.get_table("WIKI/PRICES",qopts={"columns":["date", "adj_close"]},
# ----> 8     ticker=symbol, date = {'gte': start_date,'lte' : end_date})
#       9     # specify that the quandldata df has index col = 'date'
#      10     quandldata = quandldata.set_index(["date"], drop=True)
#
# /Users/shotashimizu/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/quandl/get_table.py in get_table(datatable_code, **options)
#      17     while True:
#      18         next_options = copy.deepcopy(options)
# ---> 19         next_data = Datatable(datatable_code).data(params=next_options)
#      20
#      21         if data is None:
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-50-41245dbc8a89> in <module>()
# ----> 1 import Quandl
#       2 df = Quandl.get('GOOG/NASDAQ_GOOG')
#
# ImportError: No module named 'Quandl'

# %%
import quandl
mydata = quandl.get("FRED/GDP",start_date = start, end_date = end)

# %%
mydata
# Out:
#               Value
# Date
# 2013-01-01  16475.4
# 2013-04-01  16541.4
# 2013-07-01  16749.3
# 2013-10-01  16999.9
# 2014-01-01  17025.2

# %%
start
# Out:
# datetime.datetime(2013, 1, 1, 0, 0)

# %%
end
# Out:
# datetime.datetime(2014, 1, 1, 0, 0)

# %%
data = quandl.get_table('WIKI',paginate = True, 
                        ticker=['BP','CVX','XOM'])
# Out:
# ---------------------------------------------------------------------------
# QuandlError                               Traceback (most recent call last)
# <ipython-input-52-a0661440024a> in <module>()
#       1 data = quandl.get_table('WIKI',paginate = True,
# ----> 2                         ticker=['BP','CVX','XOM'])
#
# /Users/shotashimizu/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/quandl/get_table.py in get_table(datatable_code, **options)
#      17     while True:
#      18         next_options = copy.deepcopy(options)
# ---> 19         next_data = Datatable(datatable_code).data(params=next_options)
#      20
#      21         if data is None:
#
# /Users/shotashimizu/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/quandl/model/datatable.py in data(self, **options)
#      14     def data(self, **options):
#      15         updated_options = Util.convert_options(**options)
# ---> 16         return Data.page(self, **updated_options)
#
# ...

# %%
quandl.ApiConfig.api_key = "S7Mj12524n3ddhwLffZu"

# %%
data.iloc[:,71:90]
# Out:
#      pension_post_retire_exp  other_oper_income_exp  tot_oper_exp  \
# None
# 0                       None               -21649.0      206072.0
# 1                       None               -22570.0      195577.0
# 2                       None               -24627.0      192943.0
# 3                       None               -25285.0      180768.0
# 4                       None               -23034.0      133635.0
# 5                       None               -20268.0      116632.0
# 6                       None                -5063.0       49219.0
# 7                       None                -5260.0       55741.0
# 8                       None                -5378.0       51092.0
# 9                       None                -5948.0       50020.0
# 10                      None                -5183.0       48636.0
# 11                      None                -5420.0       50253.0
# 12                      None                -5694.0       48112.0
# ...

# %%
list(data)
# Out:
# ['m_ticker',
#  'ticker',
#  'comp_name',
#  'comp_name_2',
#  'exchange',
#  'currency_code',
#  'per_end_date',
#  'per_type',
#  'per_code',
#  'per_fisc_year',
#  'per_fisc_qtr',
#  'per_cal_year',
#  'per_cal_qtr',
#  'data_type_ind',
#  'filing_type',
#  'qtr_nbr',
#  'zacks_sector_code',
#  'zacks_x_ind_code',
#  'zacks_metrics_ind_code',
#  'fye_month',
#  'comp_cik',
#  'per_len',
#  'sic_code',
#  'filing_date',
#  'last_changed_date',
#  'state_incorp_name',
#  'bus_address_line_1',
#  'bus_city',
#  'bus_state_name',
#  'bus_post_code',
#  'bus_phone_nbr',
#  'bus_fax_nbr',
#  'mail_address_line_1',
#  'mail_city',
#  'mail_state_name',
#  'mail_post_code',
#  'country_name',
#  'country_code',
#  'home_exchange_name',
#  'emp_cnt',
#  'emp_pt_cnt',
#  'emp_ft_cnt',
#  'emp_other_cnt',
#  'comm_share_holder',
#  'auditor',
#  'auditor_opinion',
#  'comp_url',
#  'email_addr',
#  'nbr_shares_out',
#  'shares_out_date',
#  'officer_name_1',
#  'officer_title_1',
# ...

# %%
data.describe()
# Out:
#        per_fisc_year  per_fisc_qtr  per_cal_year  per_cal_qtr        qtr_nbr  \
# count      62.000000     62.000000     62.000000    62.000000      62.000000
# mean     2013.612903      2.741935   2013.612903     2.741935  162782.000000
# std         1.804864      1.200212      1.804864     1.200212   79403.277681
# min      2011.000000      1.000000   2011.000000     1.000000    2011.000000
# 25%      2012.000000      2.000000   2012.000000     2.000000  201102.250000
# 50%      2014.000000      3.000000   2014.000000     3.000000  201302.000000
# 75%      2015.000000      4.000000   2015.000000     4.000000  201501.750000
# max      2017.000000      4.000000   2017.000000     4.000000  201701.000000
#
#        zacks_sector_code  zacks_x_ind_code  zacks_metrics_ind_code  fye_month  \
# count               62.0              62.0                    62.0       62.0
# mean                12.0             132.0                    21.0       12.0
# ...

# %%
print(data.to_string())
# Out:
#      m_ticker ticker        comp_name              comp_name_2 exchange currency_code per_end_date per_type per_code  per_fisc_year  per_fisc_qtr  per_cal_year  per_cal_qtr data_type_ind filing_type  qtr_nbr  zacks_sector_code  zacks_x_ind_code  zacks_metrics_ind_code  fye_month    comp_cik per_len sic_code filing_date last_changed_date state_incorp_name          bus_address_line_1   bus_city bus_state_name bus_post_code bus_phone_nbr   bus_fax_nbr         mail_address_line_1  mail_city mail_state_name mail_post_code   country_name country_code home_exchange_name  emp_cnt emp_pt_cnt  emp_ft_cnt emp_other_cnt  comm_share_holder                     auditor auditor_opinion                         comp_url                  email_addr  nbr_shares_out shares_out_date    officer_name_1                       officer_title_1       officer_name_2                             officer_title_2          officer_name_3                             officer_title_3              officer_name_4          
# ...

# %%
data = quandl.get(['WIKI/BP','WIKI/CVX','WIKI/XOM'])

# %%
data[1:3]
# Out:
#             WIKI/BP - Open  WIKI/BP - High  WIKI/BP - Low  WIKI/BP - Close  \
# Date
# 1970-01-05             NaN             NaN            NaN              NaN
# 1970-01-06             NaN             NaN            NaN              NaN
#
#             WIKI/BP - Volume  WIKI/BP - Ex-Dividend  WIKI/BP - Split Ratio  \
# Date
# 1970-01-05               NaN                    NaN                    NaN
# 1970-01-06               NaN                    NaN                    NaN
#
#             WIKI/BP - Adj. Open  WIKI/BP - Adj. High  WIKI/BP - Adj. Low  \
# Date
# 1970-01-05                  NaN                  NaN                 NaN
# 1970-01-06                  NaN                  NaN                 NaN
#
#                      ...            WIKI/XOM - Low  WIKI/XOM - Close  \
# Date                 ...
# 1970-01-05           ...                     61.87             63.00
# 1970-01-06           ...                     62.25             62.87
#
# ...

# %%
data2 = quandl.get_table('WIKI',ticker=['BP','CVX','XOM'],
                        paginate = True)
# Out:
# ---------------------------------------------------------------------------
# QuandlError                               Traceback (most recent call last)
# <ipython-input-60-7ed75f83fd2f> in <module>()
#       1 data2 = quandl.get_table('WIKI',ticker=['BP','CVX','XOM'],
# ----> 2                         paginate = True)
#
# /Users/shotashimizu/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/quandl/get_table.py in get_table(datatable_code, **options)
#      17     while True:
#      18         next_options = copy.deepcopy(options)
# ---> 19         next_data = Datatable(datatable_code).data(params=next_options)
#      20
#      21         if data is None:
#
# /Users/shotashimizu/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/quandl/model/datatable.py in data(self, **options)
#      14     def data(self, **options):
#      15         updated_options = Util.convert_options(**options)
# ---> 16         return Data.page(self, **updated_options)
#
# ...

# %%
bp = quandl.get(['WIKI/BP.11'], start_date = start, end_date = end)

# %%
bp[1:10]
# Out:
#             WIKI/BP - Adj. Close
# Date
# 2013-01-03             32.987076
# 2013-01-04             33.284394
# 2013-01-07             33.086182
# 2013-01-08             33.086182
# 2013-01-09             33.749430
# 2013-01-10             34.313573
# 2013-01-11             33.909525
# 2013-01-14             33.802795
# 2013-01-15             33.879031

# %%
cvx = quandl.get(['WIKI/cvx.11'], start_date = start, end_date = end)

# %%
xom = quandl.get(['WIKI/xom.11'], start_date = start, end_date = end)

# %%
cvx[1:10]
# Out:
#             WIKI/cvx - Adj. Close
# Date
# 2013-01-03              92.302503
# 2013-01-04              92.789543
# 2013-01-07              92.159750
# 2013-01-08              91.748285
# 2013-01-09              91.983408
# 2013-01-10              92.764351
# 2013-01-11              93.822404
# 2013-01-14              94.762895
# 2013-01-15              95.258333

# %%
xom[1:10]
# Out:
#             WIKI/xom - Adj. Close
# Date
# 2013-01-03              76.104845
# 2013-01-04              76.457222
# 2013-01-07              75.571983
# 2013-01-08              76.044684
# 2013-01-09              75.752468
# 2013-01-10              76.577546
# 2013-01-11              77.015869
# 2013-01-14              76.990085
# 2013-01-15              76.947113

# %%
df = pd.concat([bp, cvx, xom], axis=1)

# %%
df[1:10]
# Out:
#             WIKI/BP - Adj. Close  WIKI/cvx - Adj. Close  WIKI/xom - Adj. Close
# Date
# 2013-01-03             32.987076              92.302503              76.104845
# 2013-01-04             33.284394              92.789543              76.457222
# 2013-01-07             33.086182              92.159750              75.571983
# 2013-01-08             33.086182              91.748285              76.044684
# 2013-01-09             33.749430              91.983408              75.752468
# 2013-01-10             34.313573              92.764351              76.577546
# 2013-01-11             33.909525              93.822404              77.015869
# 2013-01-14             33.802795              94.762895              76.990085
# 2013-01-15             33.879031              95.258333              76.947113

# %%
rets = df.pct_change()

# %%
rets
# Out:
#             WIKI/BP - Adj. Close  WIKI/cvx - Adj. Close  WIKI/xom - Adj. Close
# Date
# 2013-01-02                   NaN                    NaN                    NaN
# 2013-01-03              0.020038              -0.004258              -0.001804
# 2013-01-04              0.009013               0.005277               0.004630
# 2013-01-07             -0.005955              -0.006787              -0.011578
# 2013-01-08              0.000000              -0.004465               0.006255
# 2013-01-09              0.020046               0.002563              -0.003843
# 2013-01-10              0.016716               0.008490               0.010892
# 2013-01-11             -0.011775               0.011406               0.005724
# 2013-01-14             -0.003147               0.010024              -0.000335
# 2013-01-15              0.002255               0.005228              -0.000558
# 2013-01-16             -0.008101               0.004672              -0.000670
# ...

# %%
# %matplotlib inline

# %%
df.plot()

# %%
df.corr()
# Out:
#                        WIKI/BP - Adj. Close  WIKI/cvx - Adj. Close  \
# WIKI/BP - Adj. Close               1.000000               0.440195
# WIKI/cvx - Adj. Close              0.440195               1.000000
# WIKI/xom - Adj. Close              0.771631               0.599581
#
#                        WIKI/xom - Adj. Close
# WIKI/BP - Adj. Close                0.771631
# WIKI/cvx - Adj. Close               0.599581
# WIKI/xom - Adj. Close               1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(df.corr())
# Out:
# /Users/shotashimizu/.pyenv/versions/anaconda3-4.2.0/lib/python3.5/site-packages/seaborn/matrix.py:143: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   if xticklabels == []:

# %%
ser1 = Series(['w','w','x','y','x','y'])

# %%
ser1.unique()
# Out:
# array(['w', 'x', 'y'], dtype=object)

# %%
ser1.value_counts()
# Out:
# y    2
# w    2
# x    2
# dtype: int64
